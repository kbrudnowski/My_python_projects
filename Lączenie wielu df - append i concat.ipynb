# %%
import pandas as pd
import numpy as np

# %%
supliers = pd.read_csv('d:/Data_Analysis/course-files/northwind-mongo-master/suppliers.csv', usecols=['SupplierID','CompanyName','Country'])
supliers.head()
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
customers = pd.read_csv('d:/Data_Analysis/course-files/northwind-mongo-master/customers.csv', usecols=['CustomerID','CompanyName','Country'])
customers.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
len(supliers)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
supliers.append(customers)
# Out:
#     SupplierID                         CompanyName  Country CustomerID
# 0          1.0                      Exotic Liquids       UK        NaN
# 1          2.0          New Orleans Cajun Delights      USA        NaN
# 2          3.0           Grandma Kelly's Homestead      USA        NaN
# 3          4.0                       Tokyo Traders    Japan        NaN
# 4          5.0  Cooperativa de Quesos 'Las Cabras'    Spain        NaN
# ..         ...                                 ...      ...        ...
# 86         NaN                      Wartian Herkku  Finland      WARTH
# 87         NaN              Wellington Importadora   Brazil      WELLI
# 88         NaN                White Clover Markets      USA      WHITC
# 89         NaN                         Wilman Kala  Finland      WILMK
# 90         NaN                      Wolski  Zajazd   Poland      WOLZA
#
# [120 rows x 4 columns]

# %%
df_appended = supliers.append(customers, ignore_index=True)

# %%
len(df_appended)
# Out:
# 120

# %%
df_appended.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
suppliers2 = supliers.copy()
customers2 = customers.copy()

# %%
suppliers2.rename({'SupplierID':'CustomerID'}, axis='columns',inplace=True)

# %%
suppliers2.head()
# Out:
#    CustomerID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
suppliers2.append(customers2)[25:35]
# Out:
#    CustomerID                         CompanyName  Country
# 25         26                Pasta Buttini s.r.l.    Italy
# 26         27                  Escargots Nouveaux   France
# 27         28                        Gai pâturage   France
# 28         29                    Forêts d'érables   Canada
# 0       ALFKI                 Alfreds Futterkiste  Germany
# 1       ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2       ANTON            Antonio Moreno Taquer?­a   Mexico
# 3       AROUT                     Around the Horn       UK
# 4       BERGS                 Berglunds snabbk?¶p   Sweden
# 5       BLAUS             Blauer See Delikatessen  Germany

# %%
df_conctenated = pd.concat(objs=[suppliers2,customers], ignore_index=True, )

# %%
df_conctenated[25:35]
# Out:
#    CustomerID                         CompanyName  Country
# 25         26                Pasta Buttini s.r.l.    Italy
# 26         27                  Escargots Nouveaux   France
# 27         28                        Gai pâturage   France
# 28         29                    Forêts d'érables   Canada
# 29      ALFKI                 Alfreds Futterkiste  Germany
# 30      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 31      ANTON            Antonio Moreno Taquer?­a   Mexico
# 32      AROUT                     Around the Horn       UK
# 33      BERGS                 Berglunds snabbk?¶p   Sweden
# 34      BLAUS             Blauer See Delikatessen  Germany

# %% [markdown]
# # Zadanie

# %%
mrbean = pd.read_csv('d:/Data_Analysis/course-files/mrbean_facebook_statuses_join.csv', usecols=['status_message_mrbean','status_type','num_likes'])

# %%
nasa = pd.read_csv('d:/Data_Analysis/course-files/nasa_facebook_statuses_join.csv',usecols=['status_message_nasa','status_type','num_likes'])

# %%
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa.head()
# Out:
#                                  status_message_nasa status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb.head()
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 1     114008                                                NaN
# 2     218579                                                NaN
# 3      20338  Mr Bean is ready to do some shopping but bewar...
# 4     215591                                                NaN
#
#   status_message_nasa status_type
# 0                 NaN       video
# 1                 NaN       photo
# 2                 NaN       photo
# 3                 NaN       video
# 4                 NaN       photo

# %%
fb.loc[0].to_frame().transpose()
# Out:
#   num_likes                              status_message_mrbean  \
# 0     16079  It's time for Mr Bean and Teddy to get ready f...
#
#   status_message_nasa status_type
# 0                 NaN       video

# %%
mrbean.rename({'status_message_mrbean':'status_message'}, inplace=True, axis='columns')

# %%
mrbean.head()
# Out:
#                                       status_message status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa.rename({'status_message_nasa':'status_message'}, inplace=True, axis='columns')

# %%
nasa.head()
# Out:
#                                       status_message status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
fb = mrbean.append(nasa, ignore_index=True, sort=True)

# %%
fb.head()
# Out:
#    num_likes                                     status_message status_type
# 0      16079  It's time for Mr Bean and Teddy to get ready f...       video
# 1     114008                                                NaN       photo
# 2     218579                                                NaN       photo
# 3      20338  Mr Bean is ready to do some shopping but bewar...       video
# 4     215591                                                NaN       photo

# %%
fbc = fbc.c
