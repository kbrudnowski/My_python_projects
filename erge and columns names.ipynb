# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('d:/Data_Analysis/course-files/northwind-mongo-master/products.csv', usecols=['ProductID','ProductName','CategoryID','UnitPrice'])

# %%
categories = pd.read_csv('D:/Data_Analysis/course-files/northwind-mongo-master/categories1.csv', usecols=['CategoryName','CategoryID','Description'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.merge(categories).head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice CategoryName  \
# 0          1                Chai           1       18.0    Beverages
# 1          2               Chang           1       19.0    Beverages
# 2         24  Guaraná Fantástica           1        4.5    Beverages
# 3         34       Sasquatch Ale           1       14.0    Beverages
# 4         35      Steeleye Stout           1       18.0    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.rename({'CategoryID':'ID'}, axis='columns', inplace=True)

# %%
categories.head()
# Out:
#    ID    CategoryName              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(categories, right_on='ID', left_on='CategoryID').head()
# Out:
#    ProductID         ProductName  CategoryID  UnitPrice  ID CategoryName  \
# 0          1                Chai           1       18.0   1    Beverages
# 1          2               Chang           1       19.0   1    Beverages
# 2         24  Guaraná Fantástica           1        4.5   1    Beverages
# 3         34       Sasquatch Ale           1       14.0   1    Beverages
# 4         35      Steeleye Stout           1       18.0   1    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.rename({'ProductName':'Name'}, axis='columns', inplace=True)

# %%
categories.rename({'CategoryName':'Name'}, axis='columns', inplace=True)

# %%
products.head()
# Out:
#    ProductID                          Name  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(categories, right_on='ID', left_on='CategoryID', suffixes=['_prod','_category']).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
products.merge(categories, right_on='ID', left_on='CategoryID', suffixes=['_prod','_category'], sort=True).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice  ID Name_category  \
# 0          1                Chai           1       18.0   1     Beverages
# 1          2               Chang           1       19.0   1     Beverages
# 2         24  Guaraná Fantástica           1        4.5   1     Beverages
# 3         34       Sasquatch Ale           1       14.0   1     Beverages
# 4         35      Steeleye Stout           1       18.0   1     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
categories.set_index('ID',inplace=True)

# %%
products.merge(categories, right_on='ID', left_on='CategoryID', suffixes=['_prod','_category'], sort=True).head()
# Out:
#    ProductID           Name_prod  CategoryID  UnitPrice Name_category  \
# 0          1                Chai           1       18.0     Beverages
# 1          2               Chang           1       19.0     Beverages
# 2         24  Guaraná Fantástica           1        4.5     Beverages
# 3         34       Sasquatch Ale           1       14.0     Beverages
# 4         35      Steeleye Stout           1       18.0     Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks

# %%
categories.head()
# Out:
#               Name              Description
# ID
# 1        Beverages              Soft drinks
# 2       Condiments  Sweet and savory sauces
# 3      Confections                 Desserts
# 4   Dairy Products                  Cheeses
# 5   Grains/Cereals                   Breads

# %% [markdown]
# # Zadanie

# %%
suppliers = pd.read_csv("D:/Data_Analysis/course-files/northwind-mongo-master/suppliers.csv", usecols=['CompanyName','City','SupplierID'])

# %%
ProdS = pd.read_csv("D:/Data_Analysis/course-files/northwind-mongo-master/products_del_2.csv", usecols=['ProductID','ProductName','SupplierID'])

# %%
suppliers.merge(ProdS, on='SupplierID')
# Out:
#     SupplierID                CompanyName           City  ProductID  \
# 0            1             Exotic Liquids         London          1
# 1            1             Exotic Liquids         London          2
# 2            3  Grandma Kelly's Homestead      Ann Arbor          6
# 3            3  Grandma Kelly's Homestead      Ann Arbor          7
# 4            3  Grandma Kelly's Homestead      Ann Arbor          8
# ..         ...                        ...            ...        ...
# 63          25                  Ma Maison       Montréal         55
# 64          26       Pasta Buttini s.r.l.        Salerno         56
# 65          26       Pasta Buttini s.r.l.        Salerno         57
# 66          28               Gai pâturage         Annecy         60
# 67          29           Forêts d'érables  Ste-Hyacinthe         61
#
#                         ProductName
# 0                              Chai
# 1                             Chang
# 2      Grandma's Boysenberry Spread
# ...

# %%
suppliers.set_index('SupplierID', inplace=True)

# %%
suppliers.merge(ProdS, on='SupplierID')
# Out:
#     SupplierID                CompanyName           City  ProductID  \
# 0            1             Exotic Liquids         London          1
# 1            1             Exotic Liquids         London          2
# 2            3  Grandma Kelly's Homestead      Ann Arbor          6
# 3            3  Grandma Kelly's Homestead      Ann Arbor          7
# 4            3  Grandma Kelly's Homestead      Ann Arbor          8
# ..         ...                        ...            ...        ...
# 63          25                  Ma Maison       Montréal         55
# 64          26       Pasta Buttini s.r.l.        Salerno         56
# 65          26       Pasta Buttini s.r.l.        Salerno         57
# 66          28               Gai pâturage         Annecy         60
# 67          29           Forêts d'érables  Ste-Hyacinthe         61
#
#                         ProductName
# 0                              Chai
# 1                             Chang
# 2      Grandma's Boysenberry Spread
# ...

# %%
suppliers.reset_index(inplace=True)

# %%
suppliers.rename({'SupplierID':'supplier_ID'},axis='columns',inplace=True)

# %%
suppliers.merge(ProdS, right_on='supplier_ID', left_on='SupplierID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-71f2206007e0> in <module>
# ----> 1 suppliers.merge(ProdS, right_on='supplier_ID', left_on='SupplierID')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8190         from pandas.core.reshape.merge import merge
#    8191
# -> 8192         return merge(
#    8193             self,
#    8194             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ...

# %%
ProdS.head()
# Out:
#    ProductID                      ProductName  SupplierID
# 0          1                             Chai           1
# 1          2                            Chang           1
# 2          6     Grandma's Boysenberry Spread           3
# 3          7  Uncle Bob's Organic Dried Pears           3
# 4          8       Northwoods Cranberry Sauce           3
